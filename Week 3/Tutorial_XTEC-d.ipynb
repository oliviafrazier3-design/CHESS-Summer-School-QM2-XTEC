# %% [markdown]
# # XTEC-d analysis of Sr<sub>3</sub>Rh<sub>4</sub>Sn<sub>13</sub> XRD data
#
# In this tutorial, we analyze the XRD data of Sr<sub>3</sub>Rh<sub>4</sub>Sn<sub>13</sub>, a quasi-skutterudite family which shows charge density wave ordering  below a quantum critical point.
#
# This tutorial takes single-crystal x-ray diffraction data from https://dx.doi.org/10.18126/iidy-30e7
#
#
#
# ## System requirements
#
# The tutorial should run on any python version. We recommend: python 3.8 and Jupyter Notebook 6.3.0.
#
#
# ## Installing  XTEC
#
# Released versions of *XTEC* can be installed using either
#
# ```
#     $ pip install xtec
# ```
#
# or by cloning the Git repository and installing from source:
#
# ```
#     $ git clone https://github.com/KimGroup/XTEC
# ```
#
#
#
# ## XTEC codes
#
# XTEC codes are available in GitHub repository: https://github.com/KimGroup/XTEC

# %% [markdown]
# ## Required python libraries

# %%
import glob
import os
import time

import matplotlib.pyplot as plt
import numpy as np

from nexusformat.nexus import (nxgetmemory, nxload, nxsetmemory, NXdata, 
                               NXentry, NXfield)

# %% [markdown]
# ##  Required XTEC modules
#
# The following modules are to be imported for the XTEC analysis:

# %%
from xtec.Preprocessing import Mask_Zeros              # to remove zero intensity points from data       
from xtec.Preprocessing import Threshold_Background    # for thresholding background intensity

from xtec.GMM import GMM                               # for XTEC GMM clustering

# %% [markdown]
# # X-TEC flowchart
#
# The flowchart below gives the steps we follow in this tutorial.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Step A. Import the XRD Data
#
# The data loading can be customized to the type of file and structure of data stored.
#
# Ultimately, one requires a temperature series of  intensity  at (Qh, Qk, Ql) points of the 3D reciprocal lattice (or equivalently in 2D reciprocal lattice) as an array with
#
# ```
# Data. shape = (num_Temperature, num_Ql, num_Qk, num_Qh) for 3D data (equivalently for 2D data).
# ```

# %% [markdown]
# #### From https://dx.doi.org/10.18126/iidy-30e7, download the data file      ```srn0_XTEC.nxs```

# %%
base_path = "/nfs/chess/id4baux/2025-2/he-4025-d/nxrefine/Ta2NiSeS70/S1"
import os
import glob
import h5py

base_path = "/nfs/chess/id4baux/2025-2/he-4025-d/nxrefine/Ta2NiSeS70/S1"
subdirs = sorted([d for d in os.listdir(base_path) if d.isdigit()], key=int)

# Storage dictionary for memory-mapped file pointer handles
lazy_datasets = {}
DATASET_PATH = "entry/data/n"

print("--- Starting Instant Lazy Data Import ---")
for folder in subdirs:
    folder_path = os.path.join(base_path, folder)
    nxs_files = glob.glob(os.path.join(folder_path, "*.nxs"))
    
    if nxs_files:
        file_path = nxs_files[0]
        try:
            # Open file handle and leave it open
            f = h5py.File(file_path, 'r')
            if DATASET_PATH in f:
                # CRITICAL: No [:] at the end. This references the data on disk without reading it.
                lazy_datasets[folder] = f[DATASET_PATH]
                print(f"Mapped Folder {folder:3s} | Shape: {lazy_datasets[folder].shape} (0 MB RAM used)")
        except Exception as e:
            print(f"Failed folder {folder}: {e}")

print(f"\nImport finished! Loaded {len(lazy_datasets)} pointers securely.")

import dask.array as da

# 1. Sort the subdirectories numerically so your stacked axis matches ascending temperature
sorted_folders = sorted(lazy_datasets.keys(), key=int)

# 2. Convert each h5py dataset handle into a lazy Dask array pointer
lazy_arrays = [da.from_array(lazy_datasets[folder], chunks=lazy_datasets[folder].chunks) 
               for folder in sorted_folders]

# 3. Stack them cleanly along a brand new axis (Axis 0 = Temperature)
master_stacked_array = da.stack(lazy_arrays, axis=0)

print("--- Virtual Matrix Stacked Successfully ---")
print("Combined 4D Shape:", master_stacked_array.shape)
print("Data Type:", master_stacked_array.dtype)
print("RAM Used: 0 MB (Array remains safely on disk until called!)")
# Out:
# --- Starting Instant Lazy Data Import ---
# Mapped Folder 17  | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 21  | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 25  | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 30  | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 35  | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 40  | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 50  | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 60  | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 70  | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 90  | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 110 | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 115 | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 117 | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 119 | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 121 | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 123 | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 126 | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 129 | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 140 | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 150 | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 160 | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 170 | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 180 | Shape: (1191, 1721, 1221) (0 MB RAM used)
# Mapped Folder 240 | Shape: (1191, 1721, 1221) (0 MB RAM used)
#
# Import finished! Loaded 24 pointers securely.
# --- Virtual Matrix Stacked Successfully ---
# Combined 4D Shape: (24, 1191, 1721, 1221)
# Data Type: float32
# RAM Used: 0 MB (Array remains safely on disk until called!)

# %%
from nexusformat.nexus import nxload
f = nxload("/nfs/chess/id4baux/2025-2/he-4025-d/nxrefine/Ta2NiSeS70/S1/Ta2NiSeS70_110.nxs")

import h5py

def print_structure(name, obj):
    print(name)

with h5py.File('/nfs/chess/id4baux/2025-2/he-4025-d/nxrefine/Ta2NiSeS70/S1/Ta2NiSeS70_110.nxs', 'r') as f:
    f.visititems(print_structure)
    # Also print top-level attributes
    print("\nRoot attributes:", dict(f.attrs))
# Out:
# entry
# entry/instrument
# entry/instrument/detector
# entry/instrument/detector/description
# entry/instrument/detector/detector_orientation
# entry/instrument/detector/distance
# entry/instrument/detector/frame_time
# entry/instrument/detector/pitch
# entry/instrument/detector/pixel_mask
# entry/instrument/detector/pixel_size
# entry/instrument/detector/roll
# entry/instrument/detector/shape
# entry/instrument/detector/yaw
# entry/instrument/goniometer
# entry/instrument/goniometer/chi
# entry/instrument/goniometer/phi
# entry/instrument/monochromator
# entry/instrument/monochromator/energy
# entry/instrument/monochromator/wavelength
# entry/instrument/name
# entry/instrument/source
# entry/instrument/source/name
# entry/nxcombine
# entry/nxcombine/date
# entry/nxcombine/note
# entry/nxcombine/note/data
# entry/nxcombine/note/date
# entry/nxcombine/note/description
# entry/nxcombine/program
# entry/nxcombine/sequence_index
# entry/nxcombine/version
# entry/nxreduce
# entry/nxreduce/first_frame
# entry/nxreduce/hkl_tolerance
# entry/nxreduce/last_frame
# entry/nxreduce/monitor
# entry/nxreduce/norm
# entry/nxreduce/polar_max
# entry/nxreduce/qmax
# entry/nxreduce/qmin
# entry/nxreduce/radius
# entry/nxreduce/threshold
# entry/sample
# entry/sample/chemical_formula
# entry/sample/label
# entry/sample/lattice_centring
# entry/sample/laue_group
# entry/sample/name
# entry/sample/space_group
# entry/sample/unit_cell_group
# entry/sample/unitcell_a
# entry/sample/unitcell_alpha
# entry/sample/unitcell_b
# entry/sample/unitcell_beta
# entry/sample/unitcell_c
# entry/sample/unitcell_gamma
# entry/transform
# entry/transform/Qh
# entry/transform/Qk
# entry/transform/Ql
# entry/transform/title
# f1
# f1/data
# f1/data/frame_number
# f1/data/frame_time
# f1/data/monitor_weight
# f1/data/x_pixel
# f1/data/y_pixel
# f1/instrument
# f1/instrument/calibration
# f1/instrument/calibration/calibrant
# f1/instrument/calibration/header
# f1/instrument/calibration/header/ByteOrder
# f1/instrument/calibration/header/DataType
# f1/instrument/calibration/header/Dim_1
# f1/instrument/calibration/header/Dim_2
# f1/instrument/calibration/header/EDF_BinarySize
# f1/instrument/calibration/header/EDF_DataBlockID
# f1/instrument/calibration/header/EDF_HeaderSize
# f1/instrument/calibration/header/HeaderID
# f1/instrument/calibration/header/Image
# f1/instrument/calibration/header/Size
# f1/instrument/calibration/header/cutoff
# f1/instrument/calibration/header/merged_file_000
# f1/instrument/calibration/header/merged_file_001
# f1/instrument/calibration/header/merged_file_002
# f1/instrument/calibration/header/merged_file_003
# f1/instrument/calibration/header/merged_file_004
# f1/instrument/calibration/header/merged_file_005
# f1/instrument/calibration/header/merged_file_006
# f1/instrument/calibration/header/merged_file_007
# f1/instrument/calibration/header/merged_file_008
# f1/instrument/calibration/header/merged_file_009
# f1/instrument/calibration/header/merged_file_010
# f1/instrument/calibration/header/merged_file_011
# f1/instrument/calibration/header/merged_file_012
# f1/instrument/calibration/header/merged_file_013
# f1/instrument/calibration/header/merged_file_014
# f1/instrument/calibration/header/merged_file_015
# f1/instrument/calibration/header/merged_file_016
# f1/instrument/calibration/header/merged_file_017
# f1/instrument/calibration/header/merged_file_018
# f1/instrument/calibration/header/merged_file_019
# f1/instrument/calibration/header/merged_file_020
# f1/instrument/calibration/header/merged_file_021
# f1/instrument/calibration/header/merged_file_022
# f1/instrument/calibration/header/merged_file_023
# f1/instrument/calibration/header/merged_file_024
# f1/instrument/calibration/header/merged_file_025
# f1/instrument/calibration/header/merged_file_026
# f1/instrument/calibration/header/merged_file_027
# f1/instrument/calibration/header/merged_file_028
# f1/instrument/calibration/header/merged_file_029
# f1/instrument/calibration/header/merged_file_030
# f1/instrument/calibration/header/merged_file_031
# f1/instrument/calibration/header/merged_file_032
# f1/instrument/calibration/header/merged_file_033
# f1/instrument/calibration/header/merged_file_034
# f1/instrument/calibration/header/merged_file_035
# f1/instrument/calibration/header/merged_file_036
# f1/instrument/calibration/header/merged_file_037
# f1/instrument/calibration/header/merged_file_038
# f1/instrument/calibration/header/merged_file_039
# f1/instrument/calibration/header/merged_file_040
# f1/instrument/calibration/header/merged_file_041
# f1/instrument/calibration/header/merged_file_042
# f1/instrument/calibration/header/merged_file_043
# f1/instrument/calibration/header/merged_file_044
# f1/instrument/calibration/header/merged_file_045
# f1/instrument/calibration/header/merged_file_046
# f1/instrument/calibration/header/merged_file_047
# f1/instrument/calibration/header/merged_file_048
# f1/instrument/calibration/header/merged_file_049
# f1/instrument/calibration/header/merged_file_050
# f1/instrument/calibration/header/merged_file_051
# f1/instrument/calibration/header/merged_file_052
# f1/instrument/calibration/header/merged_file_053
# f1/instrument/calibration/header/merged_file_054
# f1/instrument/calibration/header/merged_file_055
# f1/instrument/calibration/header/merged_file_056
# f1/instrument/calibration/header/merged_file_057
# f1/instrument/calibration/header/merged_file_058
# f1/instrument/calibration/header/merged_file_059
# f1/instrument/calibration/header/merged_file_060
# f1/instrument/calibration/header/merged_file_061
# f1/instrument/calibration/header/merged_file_062
# f1/instrument/calibration/header/merged_file_063
# f1/instrument/calibration/header/merged_file_064
# f1/instrument/calibration/header/merged_file_065
# f1/instrument/calibration/header/merged_file_066
# f1/instrument/calibration/header/merged_file_067
# f1/instrument/calibration/header/merged_file_068
# f1/instrument/calibration/header/merged_file_069
# f1/instrument/calibration/header/merged_file_070
# f1/instrument/calibration/header/merged_file_071
# f1/instrument/calibration/header/merged_file_072
# f1/instrument/calibration/header/merged_file_073
# f1/instrument/calibration/header/merged_file_074
# f1/instrument/calibration/header/merged_file_075
# f1/instrument/calibration/header/merged_file_076
# f1/instrument/calibration/header/merged_file_077
# f1/instrument/calibration/header/merged_file_078
# f1/instrument/calibration/header/merged_file_079
# f1/instrument/calibration/header/merged_file_080
# f1/instrument/calibration/header/merged_file_081
# f1/instrument/calibration/header/merged_file_082
# f1/instrument/calibration/header/merged_file_083
# f1/instrument/calibration/header/merged_file_084
# f1/instrument/calibration/header/merged_file_085
# f1/instrument/calibration/header/merged_file_086
# f1/instrument/calibration/header/merged_file_087
# f1/instrument/calibration/header/merged_file_088
# f1/instrument/calibration/header/merged_file_089
# f1/instrument/calibration/header/merged_file_090
# f1/instrument/calibration/header/merged_file_091
# f1/instrument/calibration/header/merged_file_092
# f1/instrument/calibration/header/merged_file_093
# f1/instrument/calibration/header/merged_file_094
# f1/instrument/calibration/header/merged_file_095
# f1/instrument/calibration/header/merged_file_096
# f1/instrument/calibration/header/merged_file_097
# f1/instrument/calibration/header/merged_file_098
# f1/instrument/calibration/header/merged_file_099
# f1/instrument/calibration/header/merged_file_100
# f1/instrument/calibration/header/merged_file_101
# f1/instrument/calibration/header/merged_file_102
# f1/instrument/calibration/header/merged_file_103
# f1/instrument/calibration/header/merged_file_104
# f1/instrument/calibration/header/merged_file_105
# f1/instrument/calibration/header/merged_file_106
# f1/instrument/calibration/header/merged_file_107
# f1/instrument/calibration/header/merged_file_108
# f1/instrument/calibration/header/merged_file_109
# f1/instrument/calibration/header/merged_file_110
# f1/instrument/calibration/header/merged_file_111
# f1/instrument/calibration/header/merged_file_112
# f1/instrument/calibration/header/merged_file_113
# f1/instrument/calibration/header/merged_file_114
# f1/instrument/calibration/header/merged_file_115
# f1/instrument/calibration/header/merged_file_116
# f1/instrument/calibration/header/merged_file_117
# f1/instrument/calibration/header/merged_file_118
# f1/instrument/calibration/header/merged_file_119
# f1/instrument/calibration/header/merged_file_120
# f1/instrument/calibration/header/merged_file_121
# f1/instrument/calibration/header/merged_file_122
# f1/instrument/calibration/header/merged_file_123
# f1/instrument/calibration/header/merged_file_124
# f1/instrument/calibration/header/merged_file_125
# f1/instrument/calibration/header/merged_file_126
# f1/instrument/calibration/header/merged_file_127
# f1/instrument/calibration/header/merged_file_128
# f1/instrument/calibration/header/merged_file_129
# f1/instrument/calibration/header/merged_file_130
# f1/instrument/calibration/header/merged_file_131
# f1/instrument/calibration/header/merged_file_132
# f1/instrument/calibration/header/merged_file_133
# f1/instrument/calibration/header/merged_file_134
# f1/instrument/calibration/header/merged_file_135
# f1/instrument/calibration/header/merged_file_136
# f1/instrument/calibration/header/merged_file_137
# f1/instrument/calibration/header/merged_file_138
# f1/instrument/calibration/header/merged_file_139
# f1/instrument/calibration/header/merged_file_140
# f1/instrument/calibration/header/merged_file_141
# f1/instrument/calibration/header/merged_file_142
# f1/instrument/calibration/header/merged_file_143
# f1/instrument/calibration/header/merged_file_144
# f1/instrument/calibration/header/merged_file_145
# f1/instrument/calibration/header/merged_file_146
# f1/instrument/calibration/header/merged_file_147
# f1/instrument/calibration/header/merged_file_148
# f1/instrument/calibration/header/merged_file_149
# f1/instrument/calibration/header/merged_file_150
# f1/instrument/calibration/header/merged_file_151
# f1/instrument/calibration/header/merged_file_152
# f1/instrument/calibration/header/merged_file_153
# f1/instrument/calibration/header/merged_file_154
# f1/instrument/calibration/header/merged_file_155
# f1/instrument/calibration/header/merged_file_156
# f1/instrument/calibration/header/merged_file_157
# f1/instrument/calibration/header/merged_file_158
# f1/instrument/calibration/header/merged_file_159
# f1/instrument/calibration/header/merged_file_160
# f1/instrument/calibration/header/merged_file_161
# f1/instrument/calibration/header/merged_file_162
# f1/instrument/calibration/header/merged_file_163
# f1/instrument/calibration/header/merged_file_164
# f1/instrument/calibration/header/merged_file_165
# f1/instrument/calibration/header/merged_file_166
# f1/instrument/calibration/header/merged_file_167
# f1/instrument/calibration/header/merged_file_168
# f1/instrument/calibration/header/merged_file_169
# f1/instrument/calibration/header/merged_file_170
# f1/instrument/calibration/header/merged_file_171
# f1/instrument/calibration/header/merged_file_172
# f1/instrument/calibration/header/merged_file_173
# f1/instrument/calibration/header/merged_file_174
# f1/instrument/calibration/header/merged_file_175
# f1/instrument/calibration/header/merged_file_176
# f1/instrument/calibration/header/merged_file_177
# f1/instrument/calibration/header/merged_file_178
# f1/instrument/calibration/header/merged_file_179
# f1/instrument/calibration/header/merged_file_180
# f1/instrument/calibration/header/method
# f1/instrument/calibration/header/nfiles
# f1/instrument/calibration/header/nframes
# f1/instrument/calibration/header/quantiles
# f1/instrument/calibration/refinement
# f1/instrument/calibration/refinement/date
# f1/instrument/calibration/refinement/parameters
# f1/instrument/calibration/refinement/parameters/Detector
# f1/instrument/calibration/refinement/parameters/Distance
# f1/instrument/calibration/refinement/parameters/PixelSize1
# f1/instrument/calibration/refinement/parameters/PixelSize2
# f1/instrument/calibration/refinement/parameters/Poni1
# f1/instrument/calibration/refinement/parameters/Poni2
# f1/instrument/calibration/refinement/parameters/Rot1
# f1/instrument/calibration/refinement/parameters/Rot2
# f1/instrument/calibration/refinement/parameters/Rot3
# f1/instrument/calibration/refinement/parameters/Wavelength
# f1/instrument/calibration/refinement/program
# f1/instrument/calibration/refinement/version
# f1/instrument/calibration/title
# f1/instrument/calibration/x
# f1/instrument/calibration/y
# f1/instrument/calibration/z
# f1/instrument/detector
# f1/instrument/detector/beam_center_x
# f1/instrument/detector/beam_center_y
# f1/instrument/detector/description
# f1/instrument/detector/detector_orientation
# f1/instrument/detector/distance
# f1/instrument/detector/frame_time
# f1/instrument/detector/orientation_matrix
# f1/instrument/detector/pitch
# f1/instrument/detector/pixel_mask
# f1/instrument/detector/pixel_size
# f1/instrument/detector/polarization
# f1/instrument/detector/roll
# f1/instrument/detector/shape
# f1/instrument/detector/translation_x
# f1/instrument/detector/translation_y
# f1/instrument/detector/yaw
# f1/instrument/goniometer
# f1/instrument/goniometer/chi
# f1/instrument/goniometer/omega
# f1/instrument/goniometer/phi
# f1/instrument/goniometer/theta
# f1/instrument/goniometer/xs
# f1/instrument/goniometer/ys
# f1/instrument/goniometer/zs
# f1/instrument/monochromator
# f1/instrument/monochromator/energy
# f1/instrument/monochromator/wavelength
# f1/instrument/name
# f1/instrument/sample
# f1/instrument/source
# f1/instrument/source/name
# f1/instrument/source/probe
# f1/instrument/source/type
# f1/logs
# f1/logs/G
# f1/logs/G/G0
# f1/logs/G/G1
# f1/logs/G/G3
# f1/logs/G/G4
# f1/logs/Q
# f1/logs/T
# f1/logs/command
# f1/logs/comments
# f1/logs/counting_basis
# f1/logs/data
# f1/logs/data/Seconds
# f1/logs/data/diode
# f1/logs/data/emon
# f1/logs/data/ic1
# f1/logs/data/ic2
# f1/logs/data/nemon
# f1/logs/data/pemon
# f1/logs/data/phi
# f1/logs/date
# f1/logs/positioners
# f1/logs/positioners/Mon_Off
# f1/logs/positioners/Mond
# f1/logs/positioners/Mond_x
# f1/logs/positioners/Motor 75
# f1/logs/positioners/Motor 76
# f1/logs/positioners/Motor 77
# f1/logs/positioners/Motor 81
# f1/logs/positioners/Motor 82
# f1/logs/positioners/bsx
# f1/logs/positioners/bsy
# f1/logs/positioners/cfilter
# f1/logs/positioners/chi
# f1/logs/positioners/cryx
# f1/logs/positioners/cryy
# f1/logs/positioners/cryz
# f1/logs/positioners/curt
# f1/logs/positioners/diftabx
# f1/logs/positioners/diftabz
# f1/logs/positioners/diodex
# f1/logs/positioners/diodez
# f1/logs/positioners/dumz
# f1/logs/positioners/happhi
# f1/logs/positioners/hapx
# f1/logs/positioners/hapz
# f1/logs/positioners/mirbd
# f1/logs/positioners/mirbu
# f1/logs/positioners/mird
# f1/logs/positioners/miru
# f1/logs/positioners/monchi
# f1/logs/positioners/monphi
# f1/logs/positioners/montrav
# f1/logs/positioners/monu
# f1/logs/positioners/monu_centering
# f1/logs/positioners/monxd
# f1/logs/positioners/monxu
# f1/logs/positioners/monzd
# f1/logs/positioners/monzu
# f1/logs/positioners/mostab
# f1/logs/positioners/mu
# f1/logs/positioners/newx
# f1/logs/positioners/nu
# f1/logs/positioners/phi
# f1/logs/positioners/phi2
# f1/logs/positioners/pil6mx
# f1/logs/positioners/pil6my
# f1/logs/positioners/pil6mz
# f1/logs/positioners/pipx
# f1/logs/positioners/pipz
# f1/logs/positioners/pth
# f1/logs/positioners/ptth
# f1/logs/positioners/s1b
# f1/logs/positioners/s1l
# f1/logs/positioners/s1r
# f1/logs/positioners/s1t
# f1/logs/positioners/s1x
# f1/logs/positioners/s1z
# f1/logs/positioners/s2b
# f1/logs/positioners/s2l
# f1/logs/positioners/s2r
# f1/logs/positioners/s2t
# f1/logs/positioners/s2x
# f1/logs/positioners/s2z
# f1/logs/positioners/samx
# f1/logs/positioners/samy
# f1/logs/positioners/samz
# f1/logs/positioners/tabxd
# f1/logs/positioners/tabxu
# f1/logs/positioners/taby
# f1/logs/positioners/tabzd
# f1/logs/positioners/tabzui
# f1/logs/positioners/tabzuo
# f1/logs/positioners/th
# f1/logs/positioners/tth
# f1/logs/positioners/und_CL
# f1/logs/positioners/waferx
# f1/logs/positioners/wafery
# f1/logs/positioners/waferz
# f1/logs/positioners/wbslitbot
# f1/logs/positioners/wbslittop
# f1/logs/scan_number
# f1/logs/title
# f1/monitor
# f1/monitor/frame_number
# f1/monitor/frame_time
# f1/monitor/ic2
# f1/nxcopy
# f1/nxcopy/date
# f1/nxcopy/note
# f1/nxcopy/note/data
# f1/nxcopy/note/date
# f1/nxcopy/note/description
# f1/nxcopy/program
# f1/nxcopy/sequence_index
# f1/nxcopy/version
# f1/nxfind
# f1/nxfind/date
# f1/nxfind/first
# f1/nxfind/last
# f1/nxfind/note
# f1/nxfind/note/data
# f1/nxfind/note/date
# f1/nxfind/note/description
# f1/nxfind/program
# f1/nxfind/sequence_index
# f1/nxfind/threshold
# f1/nxfind/version
# f1/nxlink
# f1/nxlink/date
# f1/nxlink/note
# f1/nxlink/note/data
# f1/nxlink/note/date
# f1/nxlink/note/description
# f1/nxlink/program
# f1/nxlink/sequence_index
# f1/nxlink/version
# f1/nxload
# f1/nxload/date
# f1/nxload/note
# f1/nxload/note/data
# f1/nxload/note/date
# f1/nxload/note/description
# f1/nxload/program
# f1/nxload/sequence_index
# f1/nxload/version
# f1/nxmax
# f1/nxmax/date
# f1/nxmax/note
# f1/nxmax/note/data
# f1/nxmax/note/date
# f1/nxmax/note/description
# f1/nxmax/program
# f1/nxmax/qmin
# f1/nxmax/sequence_index
# f1/nxmax/version
# f1/nxrefine
# f1/nxrefine/date
# f1/nxrefine/hkl_tolerance
# f1/nxrefine/note
# f1/nxrefine/note/data
# f1/nxrefine/note/date
# f1/nxrefine/note/description
# f1/nxrefine/polar_max
# f1/nxrefine/program
# f1/nxrefine/sequence_index
# f1/nxrefine/version
# f1/nxtransform
# f1/nxtransform/date
# f1/nxtransform/monitor
# f1/nxtransform/norm
# f1/nxtransform/note
# f1/nxtransform/note/data
# f1/nxtransform/note/date
# f1/nxtransform/note/description
# f1/nxtransform/program
# f1/nxtransform/sequence_index
# f1/nxtransform/version
# f1/peaks
# f1/peaks/azimuthal_angle
# f1/peaks/intensity
# f1/peaks/polar_angle
# f1/peaks/sigx
# f1/peaks/sigy
# f1/peaks/sigz
# f1/peaks/x
# f1/peaks/y
# f1/peaks/z
# f1/radial_sum
# f1/radial_sum/Q
# f1/radial_sum/polar_angle
# f1/radial_sum/radial_sum
# f1/scan_number
# f1/start_time
# f1/summed_data
# f1/summed_data/summed_data
# f1/summed_data/summed_data_mask
# f1/summed_data/x_pixel
# f1/summed_data/y_pixel
# f1/summed_frames
# f1/summed_frames/frame_number
# f1/summed_frames/partial_frames
# f1/summed_frames/summed_frames
# f1/transform
# f1/transform/Qh
# f1/transform/Qk
# f1/transform/Ql
# f1/transform/command
# f2
# f2/data
# f2/data/frame_number
# f2/data/frame_time
# f2/data/monitor_weight
# f2/data/x_pixel
# f2/data/y_pixel
# f2/instrument
# f2/instrument/calibration
# f2/instrument/calibration/calibrant
# f2/instrument/calibration/header
# f2/instrument/calibration/header/ByteOrder
# f2/instrument/calibration/header/DataType
# f2/instrument/calibration/header/Dim_1
# f2/instrument/calibration/header/Dim_2
# f2/instrument/calibration/header/EDF_BinarySize
# f2/instrument/calibration/header/EDF_DataBlockID
# f2/instrument/calibration/header/EDF_HeaderSize
# f2/instrument/calibration/header/HeaderID
# f2/instrument/calibration/header/Image
# f2/instrument/calibration/header/Size
# f2/instrument/calibration/header/cutoff
# f2/instrument/calibration/header/merged_file_000
# f2/instrument/calibration/header/merged_file_001
# f2/instrument/calibration/header/merged_file_002
# f2/instrument/calibration/header/merged_file_003
# f2/instrument/calibration/header/merged_file_004
# f2/instrument/calibration/header/merged_file_005
# f2/instrument/calibration/header/merged_file_006
# f2/instrument/calibration/header/merged_file_007
# f2/instrument/calibration/header/merged_file_008
# f2/instrument/calibration/header/merged_file_009
# f2/instrument/calibration/header/merged_file_010
# f2/instrument/calibration/header/merged_file_011
# f2/instrument/calibration/header/merged_file_012
# f2/instrument/calibration/header/merged_file_013
# f2/instrument/calibration/header/merged_file_014
# f2/instrument/calibration/header/merged_file_015
# f2/instrument/calibration/header/merged_file_016
# f2/instrument/calibration/header/merged_file_017
# f2/instrument/calibration/header/merged_file_018
# f2/instrument/calibration/header/merged_file_019
# f2/instrument/calibration/header/merged_file_020
# f2/instrument/calibration/header/merged_file_021
# f2/instrument/calibration/header/merged_file_022
# f2/instrument/calibration/header/merged_file_023
# f2/instrument/calibration/header/merged_file_024
# f2/instrument/calibration/header/merged_file_025
# f2/instrument/calibration/header/merged_file_026
# f2/instrument/calibration/header/merged_file_027
# f2/instrument/calibration/header/merged_file_028
# f2/instrument/calibration/header/merged_file_029
# f2/instrument/calibration/header/merged_file_030
# f2/instrument/calibration/header/merged_file_031
# f2/instrument/calibration/header/merged_file_032
# f2/instrument/calibration/header/merged_file_033
# f2/instrument/calibration/header/merged_file_034
# f2/instrument/calibration/header/merged_file_035
# f2/instrument/calibration/header/merged_file_036
# f2/instrument/calibration/header/merged_file_037
# f2/instrument/calibration/header/merged_file_038
# f2/instrument/calibration/header/merged_file_039
# f2/instrument/calibration/header/merged_file_040
# f2/instrument/calibration/header/merged_file_041
# f2/instrument/calibration/header/merged_file_042
# f2/instrument/calibration/header/merged_file_043
# f2/instrument/calibration/header/merged_file_044
# f2/instrument/calibration/header/merged_file_045
# f2/instrument/calibration/header/merged_file_046
# f2/instrument/calibration/header/merged_file_047
# f2/instrument/calibration/header/merged_file_048
# f2/instrument/calibration/header/merged_file_049
# f2/instrument/calibration/header/merged_file_050
# f2/instrument/calibration/header/merged_file_051
# f2/instrument/calibration/header/merged_file_052
# f2/instrument/calibration/header/merged_file_053
# f2/instrument/calibration/header/merged_file_054
# f2/instrument/calibration/header/merged_file_055
# f2/instrument/calibration/header/merged_file_056
# f2/instrument/calibration/header/merged_file_057
# f2/instrument/calibration/header/merged_file_058
# f2/instrument/calibration/header/merged_file_059
# f2/instrument/calibration/header/merged_file_060
# f2/instrument/calibration/header/merged_file_061
# f2/instrument/calibration/header/merged_file_062
# f2/instrument/calibration/header/merged_file_063
# f2/instrument/calibration/header/merged_file_064
# f2/instrument/calibration/header/merged_file_065
# f2/instrument/calibration/header/merged_file_066
# f2/instrument/calibration/header/merged_file_067
# f2/instrument/calibration/header/merged_file_068
# f2/instrument/calibration/header/merged_file_069
# f2/instrument/calibration/header/merged_file_070
# f2/instrument/calibration/header/merged_file_071
# f2/instrument/calibration/header/merged_file_072
# f2/instrument/calibration/header/merged_file_073
# f2/instrument/calibration/header/merged_file_074
# f2/instrument/calibration/header/merged_file_075
# f2/instrument/calibration/header/merged_file_076
# f2/instrument/calibration/header/merged_file_077
# f2/instrument/calibration/header/merged_file_078
# f2/instrument/calibration/header/merged_file_079
# f2/instrument/calibration/header/merged_file_080
# f2/instrument/calibration/header/merged_file_081
# f2/instrument/calibration/header/merged_file_082
# f2/instrument/calibration/header/merged_file_083
# f2/instrument/calibration/header/merged_file_084
# f2/instrument/calibration/header/merged_file_085
# f2/instrument/calibration/header/merged_file_086
# f2/instrument/calibration/header/merged_file_087
# f2/instrument/calibration/header/merged_file_088
# f2/instrument/calibration/header/merged_file_089
# f2/instrument/calibration/header/merged_file_090
# f2/instrument/calibration/header/merged_file_091
# f2/instrument/calibration/header/merged_file_092
# f2/instrument/calibration/header/merged_file_093
# f2/instrument/calibration/header/merged_file_094
# f2/instrument/calibration/header/merged_file_095
# f2/instrument/calibration/header/merged_file_096
# f2/instrument/calibration/header/merged_file_097
# f2/instrument/calibration/header/merged_file_098
# f2/instrument/calibration/header/merged_file_099
# f2/instrument/calibration/header/merged_file_100
# f2/instrument/calibration/header/merged_file_101
# f2/instrument/calibration/header/merged_file_102
# f2/instrument/calibration/header/merged_file_103
# f2/instrument/calibration/header/merged_file_104
# f2/instrument/calibration/header/merged_file_105
# f2/instrument/calibration/header/merged_file_106
# f2/instrument/calibration/header/merged_file_107
# f2/instrument/calibration/header/merged_file_108
# f2/instrument/calibration/header/merged_file_109
# f2/instrument/calibration/header/merged_file_110
# f2/instrument/calibration/header/merged_file_111
# f2/instrument/calibration/header/merged_file_112
# f2/instrument/calibration/header/merged_file_113
# f2/instrument/calibration/header/merged_file_114
# f2/instrument/calibration/header/merged_file_115
# f2/instrument/calibration/header/merged_file_116
# f2/instrument/calibration/header/merged_file_117
# f2/instrument/calibration/header/merged_file_118
# f2/instrument/calibration/header/merged_file_119
# f2/instrument/calibration/header/merged_file_120
# f2/instrument/calibration/header/merged_file_121
# f2/instrument/calibration/header/merged_file_122
# f2/instrument/calibration/header/merged_file_123
# f2/instrument/calibration/header/merged_file_124
# f2/instrument/calibration/header/merged_file_125
# f2/instrument/calibration/header/merged_file_126
# f2/instrument/calibration/header/merged_file_127
# f2/instrument/calibration/header/merged_file_128
# f2/instrument/calibration/header/merged_file_129
# f2/instrument/calibration/header/merged_file_130
# f2/instrument/calibration/header/merged_file_131
# f2/instrument/calibration/header/merged_file_132
# f2/instrument/calibration/header/merged_file_133
# f2/instrument/calibration/header/merged_file_134
# f2/instrument/calibration/header/merged_file_135
# f2/instrument/calibration/header/merged_file_136
# f2/instrument/calibration/header/merged_file_137
# f2/instrument/calibration/header/merged_file_138
# f2/instrument/calibration/header/merged_file_139
# f2/instrument/calibration/header/merged_file_140
# f2/instrument/calibration/header/merged_file_141
# f2/instrument/calibration/header/merged_file_142
# f2/instrument/calibration/header/merged_file_143
# f2/instrument/calibration/header/merged_file_144
# f2/instrument/calibration/header/merged_file_145
# f2/instrument/calibration/header/merged_file_146
# f2/instrument/calibration/header/merged_file_147
# f2/instrument/calibration/header/merged_file_148
# f2/instrument/calibration/header/merged_file_149
# f2/instrument/calibration/header/merged_file_150
# f2/instrument/calibration/header/merged_file_151
# f2/instrument/calibration/header/merged_file_152
# f2/instrument/calibration/header/merged_file_153
# f2/instrument/calibration/header/merged_file_154
# f2/instrument/calibration/header/merged_file_155
# f2/instrument/calibration/header/merged_file_156
# f2/instrument/calibration/header/merged_file_157
# f2/instrument/calibration/header/merged_file_158
# f2/instrument/calibration/header/merged_file_159
# f2/instrument/calibration/header/merged_file_160
# f2/instrument/calibration/header/merged_file_161
# f2/instrument/calibration/header/merged_file_162
# f2/instrument/calibration/header/merged_file_163
# f2/instrument/calibration/header/merged_file_164
# f2/instrument/calibration/header/merged_file_165
# f2/instrument/calibration/header/merged_file_166
# f2/instrument/calibration/header/merged_file_167
# f2/instrument/calibration/header/merged_file_168
# f2/instrument/calibration/header/merged_file_169
# f2/instrument/calibration/header/merged_file_170
# f2/instrument/calibration/header/merged_file_171
# f2/instrument/calibration/header/merged_file_172
# f2/instrument/calibration/header/merged_file_173
# f2/instrument/calibration/header/merged_file_174
# f2/instrument/calibration/header/merged_file_175
# f2/instrument/calibration/header/merged_file_176
# f2/instrument/calibration/header/merged_file_177
# f2/instrument/calibration/header/merged_file_178
# f2/instrument/calibration/header/merged_file_179
# f2/instrument/calibration/header/merged_file_180
# f2/instrument/calibration/header/method
# f2/instrument/calibration/header/nfiles
# f2/instrument/calibration/header/nframes
# f2/instrument/calibration/header/quantiles
# f2/instrument/calibration/refinement
# f2/instrument/calibration/refinement/date
# f2/instrument/calibration/refinement/parameters
# f2/instrument/calibration/refinement/parameters/Detector
# f2/instrument/calibration/refinement/parameters/Distance
# f2/instrument/calibration/refinement/parameters/PixelSize1
# f2/instrument/calibration/refinement/parameters/PixelSize2
# f2/instrument/calibration/refinement/parameters/Poni1
# f2/instrument/calibration/refinement/parameters/Poni2
# f2/instrument/calibration/refinement/parameters/Rot1
# f2/instrument/calibration/refinement/parameters/Rot2
# f2/instrument/calibration/refinement/parameters/Rot3
# f2/instrument/calibration/refinement/parameters/Wavelength
# f2/instrument/calibration/refinement/program
# f2/instrument/calibration/refinement/version
# f2/instrument/calibration/title
# f2/instrument/calibration/x
# f2/instrument/calibration/y
# f2/instrument/calibration/z
# f2/instrument/detector
# f2/instrument/detector/beam_center_x
# f2/instrument/detector/beam_center_y
# f2/instrument/detector/description
# f2/instrument/detector/detector_orientation
# f2/instrument/detector/distance
# f2/instrument/detector/frame_time
# f2/instrument/detector/orientation_matrix
# f2/instrument/detector/pitch
# f2/instrument/detector/pixel_mask
# f2/instrument/detector/pixel_size
# f2/instrument/detector/polarization
# f2/instrument/detector/roll
# f2/instrument/detector/shape
# f2/instrument/detector/translation_x
# f2/instrument/detector/translation_y
# f2/instrument/detector/yaw
# f2/instrument/goniometer
# f2/instrument/goniometer/chi
# f2/instrument/goniometer/omega
# f2/instrument/goniometer/phi
# f2/instrument/goniometer/theta
# f2/instrument/goniometer/xs
# f2/instrument/goniometer/ys
# f2/instrument/goniometer/zs
# f2/instrument/monochromator
# f2/instrument/monochromator/energy
# f2/instrument/monochromator/wavelength
# f2/instrument/name
# f2/instrument/sample
# f2/instrument/source
# f2/instrument/source/name
# f2/instrument/source/probe
# f2/instrument/source/type
# f2/logs
# f2/logs/G
# f2/logs/G/G0
# f2/logs/G/G1
# f2/logs/G/G3
# f2/logs/G/G4
# f2/logs/Q
# f2/logs/T
# f2/logs/command
# f2/logs/comments
# f2/logs/counting_basis
# f2/logs/data
# f2/logs/data/Seconds
# f2/logs/data/diode
# f2/logs/data/emon
# f2/logs/data/ic1
# f2/logs/data/ic2
# f2/logs/data/nemon
# f2/logs/data/pemon
# f2/logs/data/phi
# f2/logs/date
# f2/logs/positioners
# f2/logs/positioners/Mon_Off
# f2/logs/positioners/Mond
# f2/logs/positioners/Mond_x
# f2/logs/positioners/Motor 75
# f2/logs/positioners/Motor 76
# f2/logs/positioners/Motor 77
# f2/logs/positioners/Motor 81
# f2/logs/positioners/Motor 82
# f2/logs/positioners/bsx
# f2/logs/positioners/bsy
# f2/logs/positioners/cfilter
# f2/logs/positioners/chi
# f2/logs/positioners/cryx
# f2/logs/positioners/cryy
# f2/logs/positioners/cryz
# f2/logs/positioners/curt
# f2/logs/positioners/diftabx
# f2/logs/positioners/diftabz
# f2/logs/positioners/diodex
# f2/logs/positioners/diodez
# f2/logs/positioners/dumz
# f2/logs/positioners/happhi
# f2/logs/positioners/hapx
# f2/logs/positioners/hapz
# f2/logs/positioners/mirbd
# f2/logs/positioners/mirbu
# f2/logs/positioners/mird
# f2/logs/positioners/miru
# f2/logs/positioners/monchi
# f2/logs/positioners/monphi
# f2/logs/positioners/montrav
# f2/logs/positioners/monu
# f2/logs/positioners/monu_centering
# f2/logs/positioners/monxd
# f2/logs/positioners/monxu
# f2/logs/positioners/monzd
# f2/logs/positioners/monzu
# f2/logs/positioners/mostab
# f2/logs/positioners/mu
# f2/logs/positioners/newx
# f2/logs/positioners/nu
# f2/logs/positioners/phi
# f2/logs/positioners/phi2
# f2/logs/positioners/pil6mx
# f2/logs/positioners/pil6my
# f2/logs/positioners/pil6mz
# f2/logs/positioners/pipx
# f2/logs/positioners/pipz
# f2/logs/positioners/pth
# f2/logs/positioners/ptth
# f2/logs/positioners/s1b
# f2/logs/positioners/s1l
# f2/logs/positioners/s1r
# f2/logs/positioners/s1t
# f2/logs/positioners/s1x
# f2/logs/positioners/s1z
# f2/logs/positioners/s2b
# f2/logs/positioners/s2l
# f2/logs/positioners/s2r
# f2/logs/positioners/s2t
# f2/logs/positioners/s2x
# f2/logs/positioners/s2z
# f2/logs/positioners/samx
# f2/logs/positioners/samy
# f2/logs/positioners/samz
# f2/logs/positioners/tabxd
# f2/logs/positioners/tabxu
# f2/logs/positioners/taby
# f2/logs/positioners/tabzd
# f2/logs/positioners/tabzui
# f2/logs/positioners/tabzuo
# f2/logs/positioners/th
# f2/logs/positioners/tth
# f2/logs/positioners/und_CL
# f2/logs/positioners/waferx
# f2/logs/positioners/wafery
# f2/logs/positioners/waferz
# f2/logs/positioners/wbslitbot
# f2/logs/positioners/wbslittop
# f2/logs/scan_number
# f2/logs/title
# f2/monitor
# f2/monitor/frame_number
# f2/monitor/frame_time
# f2/monitor/ic2
# f2/nxcopy
# f2/nxcopy/date
# f2/nxcopy/note
# f2/nxcopy/note/data
# f2/nxcopy/note/date
# f2/nxcopy/note/description
# f2/nxcopy/program
# f2/nxcopy/sequence_index
# f2/nxcopy/version
# f2/nxfind
# f2/nxfind/date
# f2/nxfind/first
# f2/nxfind/last
# f2/nxfind/note
# f2/nxfind/note/data
# f2/nxfind/note/date
# f2/nxfind/note/description
# f2/nxfind/program
# f2/nxfind/sequence_index
# f2/nxfind/threshold
# f2/nxfind/version
# f2/nxlink
# f2/nxlink/date
# f2/nxlink/note
# f2/nxlink/note/data
# f2/nxlink/note/date
# f2/nxlink/note/description
# f2/nxlink/program
# f2/nxlink/sequence_index
# f2/nxlink/version
# f2/nxload
# f2/nxload/date
# f2/nxload/note
# f2/nxload/note/data
# f2/nxload/note/date
# f2/nxload/note/description
# f2/nxload/program
# f2/nxload/sequence_index
# f2/nxload/version
# f2/nxmax
# f2/nxmax/date
# f2/nxmax/note
# f2/nxmax/note/data
# f2/nxmax/note/date
# f2/nxmax/note/description
# f2/nxmax/program
# f2/nxmax/qmin
# f2/nxmax/sequence_index
# f2/nxmax/version
# f2/nxrefine
# f2/nxrefine/date
# f2/nxrefine/hkl_tolerance
# f2/nxrefine/note
# f2/nxrefine/note/data
# f2/nxrefine/note/date
# f2/nxrefine/note/description
# f2/nxrefine/polar_max
# f2/nxrefine/program
# f2/nxrefine/sequence_index
# f2/nxrefine/version
# f2/nxtransform
# f2/nxtransform/date
# f2/nxtransform/monitor
# f2/nxtransform/norm
# f2/nxtransform/note
# f2/nxtransform/note/data
# f2/nxtransform/note/date
# f2/nxtransform/note/description
# f2/nxtransform/program
# f2/nxtransform/sequence_index
# f2/nxtransform/version
# f2/peaks
# f2/peaks/azimuthal_angle
# f2/peaks/intensity
# f2/peaks/polar_angle
# f2/peaks/sigx
# f2/peaks/sigy
# f2/peaks/sigz
# f2/peaks/x
# f2/peaks/y
# f2/peaks/z
# f2/radial_sum
# f2/radial_sum/Q
# f2/radial_sum/polar_angle
# f2/radial_sum/radial_sum
# f2/scan_number
# f2/start_time
# f2/summed_data
# f2/summed_data/summed_data
# f2/summed_data/summed_data_mask
# f2/summed_data/x_pixel
# f2/summed_data/y_pixel
# f2/summed_frames
# f2/summed_frames/frame_number
# f2/summed_frames/partial_frames
# f2/summed_frames/summed_frames
# f2/transform
# f2/transform/Qh
# f2/transform/Qk
# f2/transform/Ql
# f2/transform/command
# f3
# f3/data
# f3/data/frame_number
# f3/data/frame_time
# f3/data/monitor_weight
# f3/data/x_pixel
# f3/data/y_pixel
# f3/instrument
# f3/instrument/calibration
# f3/instrument/calibration/calibrant
# f3/instrument/calibration/header
# f3/instrument/calibration/header/ByteOrder
# f3/instrument/calibration/header/DataType
# f3/instrument/calibration/header/Dim_1
# f3/instrument/calibration/header/Dim_2
# f3/instrument/calibration/header/EDF_BinarySize
# f3/instrument/calibration/header/EDF_DataBlockID
# f3/instrument/calibration/header/EDF_HeaderSize
# f3/instrument/calibration/header/HeaderID
# f3/instrument/calibration/header/Image
# f3/instrument/calibration/header/Size
# f3/instrument/calibration/header/cutoff
# f3/instrument/calibration/header/merged_file_000
# f3/instrument/calibration/header/merged_file_001
# f3/instrument/calibration/header/merged_file_002
# f3/instrument/calibration/header/merged_file_003
# f3/instrument/calibration/header/merged_file_004
# f3/instrument/calibration/header/merged_file_005
# f3/instrument/calibration/header/merged_file_006
# f3/instrument/calibration/header/merged_file_007
# f3/instrument/calibration/header/merged_file_008
# f3/instrument/calibration/header/merged_file_009
# f3/instrument/calibration/header/merged_file_010
# f3/instrument/calibration/header/merged_file_011
# f3/instrument/calibration/header/merged_file_012
# f3/instrument/calibration/header/merged_file_013
# f3/instrument/calibration/header/merged_file_014
# f3/instrument/calibration/header/merged_file_015
# f3/instrument/calibration/header/merged_file_016
# f3/instrument/calibration/header/merged_file_017
# f3/instrument/calibration/header/merged_file_018
# f3/instrument/calibration/header/merged_file_019
# f3/instrument/calibration/header/merged_file_020
# f3/instrument/calibration/header/merged_file_021
# f3/instrument/calibration/header/merged_file_022
# f3/instrument/calibration/header/merged_file_023
# f3/instrument/calibration/header/merged_file_024
# f3/instrument/calibration/header/merged_file_025
# f3/instrument/calibration/header/merged_file_026
# f3/instrument/calibration/header/merged_file_027
# f3/instrument/calibration/header/merged_file_028
# f3/instrument/calibration/header/merged_file_029
# f3/instrument/calibration/header/merged_file_030
# f3/instrument/calibration/header/merged_file_031
# f3/instrument/calibration/header/merged_file_032
# f3/instrument/calibration/header/merged_file_033
# f3/instrument/calibration/header/merged_file_034
# f3/instrument/calibration/header/merged_file_035
# f3/instrument/calibration/header/merged_file_036
# f3/instrument/calibration/header/merged_file_037
# f3/instrument/calibration/header/merged_file_038
# f3/instrument/calibration/header/merged_file_039
# f3/instrument/calibration/header/merged_file_040
# f3/instrument/calibration/header/merged_file_041
# f3/instrument/calibration/header/merged_file_042
# f3/instrument/calibration/header/merged_file_043
# f3/instrument/calibration/header/merged_file_044
# f3/instrument/calibration/header/merged_file_045
# f3/instrument/calibration/header/merged_file_046
# f3/instrument/calibration/header/merged_file_047
# f3/instrument/calibration/header/merged_file_048
# f3/instrument/calibration/header/merged_file_049
# f3/instrument/calibration/header/merged_file_050
# f3/instrument/calibration/header/merged_file_051
# f3/instrument/calibration/header/merged_file_052
# f3/instrument/calibration/header/merged_file_053
# f3/instrument/calibration/header/merged_file_054
# f3/instrument/calibration/header/merged_file_055
# f3/instrument/calibration/header/merged_file_056
# f3/instrument/calibration/header/merged_file_057
# f3/instrument/calibration/header/merged_file_058
# f3/instrument/calibration/header/merged_file_059
# f3/instrument/calibration/header/merged_file_060
# f3/instrument/calibration/header/merged_file_061
# f3/instrument/calibration/header/merged_file_062
# f3/instrument/calibration/header/merged_file_063
# f3/instrument/calibration/header/merged_file_064
# f3/instrument/calibration/header/merged_file_065
# f3/instrument/calibration/header/merged_file_066
# f3/instrument/calibration/header/merged_file_067
# f3/instrument/calibration/header/merged_file_068
# f3/instrument/calibration/header/merged_file_069
# f3/instrument/calibration/header/merged_file_070
# f3/instrument/calibration/header/merged_file_071
# f3/instrument/calibration/header/merged_file_072
# f3/instrument/calibration/header/merged_file_073
# f3/instrument/calibration/header/merged_file_074
# f3/instrument/calibration/header/merged_file_075
# f3/instrument/calibration/header/merged_file_076
# f3/instrument/calibration/header/merged_file_077
# f3/instrument/calibration/header/merged_file_078
# f3/instrument/calibration/header/merged_file_079
# f3/instrument/calibration/header/merged_file_080
# f3/instrument/calibration/header/merged_file_081
# f3/instrument/calibration/header/merged_file_082
# f3/instrument/calibration/header/merged_file_083
# f3/instrument/calibration/header/merged_file_084
# f3/instrument/calibration/header/merged_file_085
# f3/instrument/calibration/header/merged_file_086
# f3/instrument/calibration/header/merged_file_087
# f3/instrument/calibration/header/merged_file_088
# f3/instrument/calibration/header/merged_file_089
# f3/instrument/calibration/header/merged_file_090
# f3/instrument/calibration/header/merged_file_091
# f3/instrument/calibration/header/merged_file_092
# f3/instrument/calibration/header/merged_file_093
# f3/instrument/calibration/header/merged_file_094
# f3/instrument/calibration/header/merged_file_095
# f3/instrument/calibration/header/merged_file_096
# f3/instrument/calibration/header/merged_file_097
# f3/instrument/calibration/header/merged_file_098
# f3/instrument/calibration/header/merged_file_099
# f3/instrument/calibration/header/merged_file_100
# f3/instrument/calibration/header/merged_file_101
# f3/instrument/calibration/header/merged_file_102
# f3/instrument/calibration/header/merged_file_103
# f3/instrument/calibration/header/merged_file_104
# f3/instrument/calibration/header/merged_file_105
# f3/instrument/calibration/header/merged_file_106
# f3/instrument/calibration/header/merged_file_107
# f3/instrument/calibration/header/merged_file_108
# f3/instrument/calibration/header/merged_file_109
# f3/instrument/calibration/header/merged_file_110
# f3/instrument/calibration/header/merged_file_111
# f3/instrument/calibration/header/merged_file_112
# f3/instrument/calibration/header/merged_file_113
# f3/instrument/calibration/header/merged_file_114
# f3/instrument/calibration/header/merged_file_115
# f3/instrument/calibration/header/merged_file_116
# f3/instrument/calibration/header/merged_file_117
# f3/instrument/calibration/header/merged_file_118
# f3/instrument/calibration/header/merged_file_119
# f3/instrument/calibration/header/merged_file_120
# f3/instrument/calibration/header/merged_file_121
# f3/instrument/calibration/header/merged_file_122
# f3/instrument/calibration/header/merged_file_123
# f3/instrument/calibration/header/merged_file_124
# f3/instrument/calibration/header/merged_file_125
# f3/instrument/calibration/header/merged_file_126
# f3/instrument/calibration/header/merged_file_127
# f3/instrument/calibration/header/merged_file_128
# f3/instrument/calibration/header/merged_file_129
# f3/instrument/calibration/header/merged_file_130
# f3/instrument/calibration/header/merged_file_131
# f3/instrument/calibration/header/merged_file_132
# f3/instrument/calibration/header/merged_file_133
# f3/instrument/calibration/header/merged_file_134
# f3/instrument/calibration/header/merged_file_135
# f3/instrument/calibration/header/merged_file_136
# f3/instrument/calibration/header/merged_file_137
# f3/instrument/calibration/header/merged_file_138
# f3/instrument/calibration/header/merged_file_139
# f3/instrument/calibration/header/merged_file_140
# f3/instrument/calibration/header/merged_file_141
# f3/instrument/calibration/header/merged_file_142
# f3/instrument/calibration/header/merged_file_143
# f3/instrument/calibration/header/merged_file_144
# f3/instrument/calibration/header/merged_file_145
# f3/instrument/calibration/header/merged_file_146
# f3/instrument/calibration/header/merged_file_147
# f3/instrument/calibration/header/merged_file_148
# f3/instrument/calibration/header/merged_file_149
# f3/instrument/calibration/header/merged_file_150
# f3/instrument/calibration/header/merged_file_151
# f3/instrument/calibration/header/merged_file_152
# f3/instrument/calibration/header/merged_file_153
# f3/instrument/calibration/header/merged_file_154
# f3/instrument/calibration/header/merged_file_155
# f3/instrument/calibration/header/merged_file_156
# f3/instrument/calibration/header/merged_file_157
# f3/instrument/calibration/header/merged_file_158
# f3/instrument/calibration/header/merged_file_159
# f3/instrument/calibration/header/merged_file_160
# f3/instrument/calibration/header/merged_file_161
# f3/instrument/calibration/header/merged_file_162
# f3/instrument/calibration/header/merged_file_163
# f3/instrument/calibration/header/merged_file_164
# f3/instrument/calibration/header/merged_file_165
# f3/instrument/calibration/header/merged_file_166
# f3/instrument/calibration/header/merged_file_167
# f3/instrument/calibration/header/merged_file_168
# f3/instrument/calibration/header/merged_file_169
# f3/instrument/calibration/header/merged_file_170
# f3/instrument/calibration/header/merged_file_171
# f3/instrument/calibration/header/merged_file_172
# f3/instrument/calibration/header/merged_file_173
# f3/instrument/calibration/header/merged_file_174
# f3/instrument/calibration/header/merged_file_175
# f3/instrument/calibration/header/merged_file_176
# f3/instrument/calibration/header/merged_file_177
# f3/instrument/calibration/header/merged_file_178
# f3/instrument/calibration/header/merged_file_179
# f3/instrument/calibration/header/merged_file_180
# f3/instrument/calibration/header/method
# f3/instrument/calibration/header/nfiles
# f3/instrument/calibration/header/nframes
# f3/instrument/calibration/header/quantiles
# f3/instrument/calibration/refinement
# f3/instrument/calibration/refinement/date
# f3/instrument/calibration/refinement/parameters
# f3/instrument/calibration/refinement/parameters/Detector
# f3/instrument/calibration/refinement/parameters/Distance
# f3/instrument/calibration/refinement/parameters/PixelSize1
# f3/instrument/calibration/refinement/parameters/PixelSize2
# f3/instrument/calibration/refinement/parameters/Poni1
# f3/instrument/calibration/refinement/parameters/Poni2
# f3/instrument/calibration/refinement/parameters/Rot1
# f3/instrument/calibration/refinement/parameters/Rot2
# f3/instrument/calibration/refinement/parameters/Rot3
# f3/instrument/calibration/refinement/parameters/Wavelength
# f3/instrument/calibration/refinement/program
# f3/instrument/calibration/refinement/version
# f3/instrument/calibration/title
# f3/instrument/calibration/x
# f3/instrument/calibration/y
# f3/instrument/calibration/z
# f3/instrument/detector
# f3/instrument/detector/beam_center_x
# f3/instrument/detector/beam_center_y
# f3/instrument/detector/description
# f3/instrument/detector/detector_orientation
# f3/instrument/detector/distance
# f3/instrument/detector/frame_time
# f3/instrument/detector/orientation_matrix
# f3/instrument/detector/pitch
# f3/instrument/detector/pixel_mask
# f3/instrument/detector/pixel_size
# f3/instrument/detector/polarization
# f3/instrument/detector/roll
# f3/instrument/detector/shape
# f3/instrument/detector/translation_x
# f3/instrument/detector/translation_y
# f3/instrument/detector/yaw
# f3/instrument/goniometer
# f3/instrument/goniometer/chi
# f3/instrument/goniometer/omega
# f3/instrument/goniometer/phi
# f3/instrument/goniometer/theta
# f3/instrument/goniometer/xs
# f3/instrument/goniometer/ys
# f3/instrument/goniometer/zs
# f3/instrument/monochromator
# f3/instrument/monochromator/energy
# f3/instrument/monochromator/wavelength
# f3/instrument/name
# f3/instrument/sample
# f3/instrument/source
# f3/instrument/source/name
# f3/instrument/source/probe
# f3/instrument/source/type
# f3/logs
# f3/logs/G
# f3/logs/G/G0
# f3/logs/G/G1
# f3/logs/G/G3
# f3/logs/G/G4
# f3/logs/Q
# f3/logs/T
# f3/logs/command
# f3/logs/comments
# f3/logs/counting_basis
# f3/logs/data
# f3/logs/data/Seconds
# f3/logs/data/diode
# f3/logs/data/emon
# f3/logs/data/ic1
# f3/logs/data/ic2
# f3/logs/data/nemon
# f3/logs/data/pemon
# f3/logs/data/phi
# f3/logs/date
# f3/logs/positioners
# f3/logs/positioners/Mon_Off
# f3/logs/positioners/Mond
# f3/logs/positioners/Mond_x
# f3/logs/positioners/Motor 75
# f3/logs/positioners/Motor 76
# f3/logs/positioners/Motor 77
# f3/logs/positioners/Motor 81
# f3/logs/positioners/Motor 82
# f3/logs/positioners/bsx
# f3/logs/positioners/bsy
# f3/logs/positioners/cfilter
# f3/logs/positioners/chi
# f3/logs/positioners/cryx
# f3/logs/positioners/cryy
# f3/logs/positioners/cryz
# f3/logs/positioners/curt
# f3/logs/positioners/diftabx
# f3/logs/positioners/diftabz
# f3/logs/positioners/diodex
# f3/logs/positioners/diodez
# f3/logs/positioners/dumz
# f3/logs/positioners/happhi
# f3/logs/positioners/hapx
# f3/logs/positioners/hapz
# f3/logs/positioners/mirbd
# f3/logs/positioners/mirbu
# f3/logs/positioners/mird
# f3/logs/positioners/miru
# f3/logs/positioners/monchi
# f3/logs/positioners/monphi
# f3/logs/positioners/montrav
# f3/logs/positioners/monu
# f3/logs/positioners/monu_centering
# f3/logs/positioners/monxd
# f3/logs/positioners/monxu
# f3/logs/positioners/monzd
# f3/logs/positioners/monzu
# f3/logs/positioners/mostab
# f3/logs/positioners/mu
# f3/logs/positioners/newx
# f3/logs/positioners/nu
# f3/logs/positioners/phi
# f3/logs/positioners/phi2
# f3/logs/positioners/pil6mx
# f3/logs/positioners/pil6my
# f3/logs/positioners/pil6mz
# f3/logs/positioners/pipx
# f3/logs/positioners/pipz
# f3/logs/positioners/pth
# f3/logs/positioners/ptth
# f3/logs/positioners/s1b
# f3/logs/positioners/s1l
# f3/logs/positioners/s1r
# f3/logs/positioners/s1t
# f3/logs/positioners/s1x
# f3/logs/positioners/s1z
# f3/logs/positioners/s2b
# f3/logs/positioners/s2l
# f3/logs/positioners/s2r
# f3/logs/positioners/s2t
# f3/logs/positioners/s2x
# f3/logs/positioners/s2z
# f3/logs/positioners/samx
# f3/logs/positioners/samy
# f3/logs/positioners/samz
# f3/logs/positioners/tabxd
# f3/logs/positioners/tabxu
# f3/logs/positioners/taby
# f3/logs/positioners/tabzd
# f3/logs/positioners/tabzui
# f3/logs/positioners/tabzuo
# f3/logs/positioners/th
# f3/logs/positioners/tth
# f3/logs/positioners/und_CL
# f3/logs/positioners/waferx
# f3/logs/positioners/wafery
# f3/logs/positioners/waferz
# f3/logs/positioners/wbslitbot
# f3/logs/positioners/wbslittop
# f3/logs/scan_number
# f3/logs/title
# f3/monitor
# f3/monitor/frame_number
# f3/monitor/frame_time
# f3/monitor/ic2
# f3/nxcopy
# f3/nxcopy/date
# f3/nxcopy/note
# f3/nxcopy/note/data
# f3/nxcopy/note/date
# f3/nxcopy/note/description
# f3/nxcopy/program
# f3/nxcopy/sequence_index
# f3/nxcopy/version
# f3/nxfind
# f3/nxfind/date
# f3/nxfind/first
# f3/nxfind/last
# f3/nxfind/note
# f3/nxfind/note/data
# f3/nxfind/note/date
# f3/nxfind/note/description
# f3/nxfind/program
# f3/nxfind/sequence_index
# f3/nxfind/threshold
# f3/nxfind/version
# f3/nxlink
# f3/nxlink/date
# f3/nxlink/note
# f3/nxlink/note/data
# f3/nxlink/note/date
# f3/nxlink/note/description
# f3/nxlink/program
# f3/nxlink/sequence_index
# f3/nxlink/version
# f3/nxload
# f3/nxload/date
# f3/nxload/note
# f3/nxload/note/data
# f3/nxload/note/date
# f3/nxload/note/description
# f3/nxload/program
# f3/nxload/sequence_index
# f3/nxload/version
# f3/nxmax
# f3/nxmax/date
# f3/nxmax/note
# f3/nxmax/note/data
# f3/nxmax/note/date
# f3/nxmax/note/description
# f3/nxmax/program
# f3/nxmax/qmin
# f3/nxmax/sequence_index
# f3/nxmax/version
# f3/nxrefine
# f3/nxrefine/date
# f3/nxrefine/hkl_tolerance
# f3/nxrefine/note
# f3/nxrefine/note/data
# f3/nxrefine/note/date
# f3/nxrefine/note/description
# f3/nxrefine/polar_max
# f3/nxrefine/program
# f3/nxrefine/sequence_index
# f3/nxrefine/version
# f3/nxtransform
# f3/nxtransform/date
# f3/nxtransform/monitor
# f3/nxtransform/norm
# f3/nxtransform/note
# f3/nxtransform/note/data
# f3/nxtransform/note/date
# f3/nxtransform/note/description
# f3/nxtransform/program
# f3/nxtransform/sequence_index
# f3/nxtransform/version
# f3/peaks
# f3/peaks/azimuthal_angle
# f3/peaks/intensity
# f3/peaks/polar_angle
# f3/peaks/sigx
# f3/peaks/sigy
# f3/peaks/sigz
# f3/peaks/x
# f3/peaks/y
# f3/peaks/z
# f3/radial_sum
# f3/radial_sum/Q
# f3/radial_sum/polar_angle
# f3/radial_sum/radial_sum
# f3/scan_number
# f3/start_time
# f3/summed_data
# f3/summed_data/summed_data
# f3/summed_data/summed_data_mask
# f3/summed_data/x_pixel
# f3/summed_data/y_pixel
# f3/summed_frames
# f3/summed_frames/frame_number
# f3/summed_frames/partial_frames
# f3/summed_frames/summed_frames
# f3/transform
# f3/transform/Qh
# f3/transform/Qk
# f3/transform/Ql
# f3/transform/command
#
# Root attributes: {'default': 'entry'}

# %%
print(f['f2']['data']['data'])

# %%
I = data.nxsignal.nxvalue    # intensities, shape= (num_Temperature, num_Ql, num_Qk, num_Qh)
Qh = data['Qh'].nxvalue      # Qh in r.l.u
Qk = data['Qk'].nxvalue      # Qk in r.l.u
Ql = data['Ql'].nxvalue      # Ql in r.l.u
Temp = data['Te'].nxvalue    # Temperatures
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 I = data.nxsignal.nxvalue    # intensities, shape= (num_Temperature, num_Ql, num_Qk, num_Qh)
#       2 Qh = data['Qh'].nxvalue      # Qh in r.l.u
#       3 Qk = data['Qk'].nxvalue      # Qk in r.l.u
#
# NameError: name 'data' is not defined

# %% [markdown]
# # Step B. Threshold background intensity
#
# The data is first put through a preprocessing to remove low intensity background noise. Assumes that the peaks/relevant x-ray features are sparse so that most momenta have predominantely background intensity contributions.
#
# Cutoff automatically estimated by minimizing the Kullback-Leibler (KL) distance between the distribution of $\log[\overline{I_q(T)}]$ and a Gaussian distribution with (high intensity) sliding cutoff. See supplementary materials of  Venderley et al., https://arxiv.org/abs/2008.03275.
#
# See preprocessing.py for comments on the code

# %%
start_time = time.time()

masked    = Mask_Zeros(I)       # removes data with zero intensity. 
threshold = Threshold_Background(masked)    # remove low intensity background

print("Thresholding Run Time:",time.time() - start_time)

# %% [markdown]
# The results from thresholding are stored as
#
#
# ```
#     1.  threshold.data_thresholded : contains  thresholded data.
#                                      Shape=(num_T, num_thresholded_data)
#
#     2.  threshold.ind_thresholded  : contains hkl indices of the thresholded data.
#                                    Shape=(num_data_thresholded, 3) for 3D or (num_data_thresholded, 2) for 2D.
#
#     3.  threshold.thresholded      :  stores whether the corresponding pixel is removed (=0) or not (=1).
#                                       Shape=(num_l, num_k, num_h) or shape=(num_k, num_h)
# ```

# %%
Data_thresh     = threshold.data_thresholded  # shape=(num_temperatures, num_thresholded data)
Data_ind        = threshold.ind_thresholded           # contains hkl indices of the thresholded data.

print('num of original data pixels=', np.prod(I.shape[1:])) 
print('num of thresholded data pixels=', Data_thresh.shape[1])

# %% [markdown]
# Let us see the thresholding results. Below is the distribution of intensities $(\log[\overline{I_q(T)}])$ and the truncation point (red dot) determined by thresholding. Only intensities above the truncation are retained.

# %%
figsize_=(10,5)
threshold.plot_cutoff(figsize_)

# %% [markdown]
# Note the non Gaussian features in the distribution just above the cutoff intensity (red dot). Those are the useful data we are after.
#
# All data points that have $\log[\overline{I_q(T)}]$ above estimated cutoff are retained. The plot below shows those remaining points in the hk plane as grey clusters

# %%
figsize_=(8,8)

axis_ind = 0   # Select 0 for plotting l plane, 1 for k plane, 2 for h plane
slice_value = 0.0 # Value of the axis orthogonal to the selected plane
slice_ind = data.nxaxes[axis_ind+1].index(slice_value) # index of  the selected axis (h/k/l plane) to plot

threshold.plot_thresholding_2D_slice(figsize_, slice_ind, axis_ind)

# threshold.plot_thresholding_2D_slice(figsize_, slice_ind_, axis_) : plots the 2D image 
# with points whose intensity distribution is above the cutoff marked as grey. 
# if data is 3D, then set the slice ind and axis_ (default=None) to select the index of the 2D slice along axis_ =0,1 or 2.

ax = plt.gca()
ax.get_images()[0].set_extent((Qh[0], Qh[-1], Qk[0], Qk[-1])) 
plt.xlabel('H')
plt.ylabel('K')
plt.title(f'L={slice_value}')

# %% [markdown]
# # Step. C Rescale intensity
#
#
# To reduce the large range in the scale of intensities and for efficient feature selection of the temperature trajectory, we provide two options to rescale intensities $I_q(T)$:
#
#
# #### Rescaling by mean:
# subtracting and dividing their mean over temperature $\mu_{\vec{q}_i}=d_T^{-1}\sum_j I_{\vec{q}_i}(T_j)$  for each $q$,
#
#
# \begin{eqnarray}
# 	\tilde{I}_{\vec{q}_i}(T_j)=\dfrac{I_{\vec{q}_i}(T_j)}{\mu_{\vec{q}_i}}-1,\label{eq:mean_rescaling}
# 	\end{eqnarray}
#
#
# #### Z-scoring the data:
# subtracting the mean (over T) and then dividing by standard deviation (over T)
#
# \begin{eqnarray}
# 	\tilde{I}_{\vec{q}_i}(T_j)=\dfrac{I_{\vec{q}_i}(T_j)-\mu_{\vec q_i}}{\sigma_{\vec{q}_i}},
# \end{eqnarray}
#
# where $\sigma_{\vec{q}_i}=\sqrt{d_T^{-1}\sum_j \left(I_{\vec{q}_i}(T_j)-\mu_{\vec q_i}\right)^2}$ is the standard deviation.

# %%
Rescaled_data=threshold.Rescale_mean(Data_thresh)      # rescale by mean

#Rescaled_data=threshold.Rescale_zscore(data)   # rescale by z-score


print('num of thresholded (and rescaled) data = ', Rescaled_data.shape[1] )
print('num T = ', Rescaled_data.shape[0])

# %% [markdown]
# ## Optional step: remove data with low variance in temperature (for faster results)
#
# To see faster results, and when large number of data post thresholding is made of noise, this step removes the noisy data by eliminating low variance trajectories. We have to however set the cutoff manually

# %%
#cutoff=0.3
#threshold.Get_High_Variance(Rescaled_data,cutoff)   # get (rescaled) data with std_dev (in T) > cutoff               
    
#Rescaled_data=threshold.data_high_std_dev        # The high variance data, shape=(num_T, num_high_var_data) 
#Data_ind    = threshold.ind_high_std_dev    # (hkl) indices of high var data, shape=(num_high_var_data,3)

# %% [markdown]
# The downside is the setting of manual cutoff for this step.
# ###### Recommended course of action: Cluster without any cutoff on smaller datasets.  Apply cutoff on larger datasets for faster results

# %% [markdown]
# # Step D: set number of clusters
#
# Start with an initial guess (say 3 or 4), and run till step F (visualization). Revisit this step to change the num of clusters to arrive at the optimal choice.

# %%
num_clusters = 4

# %% [markdown]
# # Step E.1:  XTEC-d  (vanilla GMM)
#
# We first apply simple GMM clustering. Here temperature series of intensity at each $q$ point is clustered independently.

# %%
Data_for_GMM    = Rescaled_data.transpose()       # data should be arranged as (num_data,num_T) for GMM

start_time = time.time()
clusterGMM = GMM(Data_for_GMM, num_clusters) # set the data and number of clusters for GMM
clusterGMM.RunEM()                          # performs the simple EM algorithm to cluster trajectories
print("GMM Run Time:",time.time() - start_time)

cluster_assignments = clusterGMM.cluster_assignments 
print('num of trajectories in each cluster = ', clusterGMM.num_per_cluster)

# %% [markdown]
# Clustering results are stored in clusterGMM as
#
# ```
# clusterGMM.cluster_assignments : cluster assignment k in range(num_clusters), of each sample. Shape=(num_data)
# clusterGMM.num_per_cluster : number of trajectories in each cluster.
#
# clusterGMM.cluster[k].mean: cluster mean trajectory (dim=num_Temperature) of the k-th cluster
# clusterGMM.cluster[k].cov : cluster covariance [dim=num_Temperature] of the k-th cluster
# ```

# %% [markdown]
# ### Store the clustering results:

# %% [markdown]
# # Step F. Visualization of clustered results.
#
# Let us plot the cluster mean of the rescaled data (lines), with 1 standard deviation shaded, for the clusters color coded as red blue green violet etc.

# %%
clusterGMM.Plot_Cluster_Results_traj(Temp)  # Plotting for only less than 7 clusters currently enabled.  

plt.xlabel('T(K)', size=18)
plt.ylabel('$\widetilde{I}_q(T)$', size=18)
plt.title('Cluster mean and variance \n (rescaled) intensity trajectory ');

# %% [markdown]
# The order parameter like behavior of one of the cluster is apparent from here, with a transition temperature $T_c\approx 130 K$ This cluster corresponds to the CDW peak. To see that, let us plot and see which pixels in the $(h,k)$ plane belong to the red/blue/green/violet cluster.

# %%
figsize_ = (8,8)

axis_ind = 0   # Select 0 for plotting l plane, 1 for k plane, 2 for h plane 
slice_value = 0.0 # Value of the axis orthogonal to the selected plane
slice_ind = data.nxaxes[axis_ind+1].index(slice_value) # index of  the selected axis (h/k/l plane) to plot

Data_for_GMM_ind =  Data_ind  #(hkl) indices of the data that was clustered 

clusterGMM.Plot_Cluster_kspace_2D_slice(threshold, figsize_, Data_for_GMM_ind, slice_ind, axis_ind) 

ax = plt.gca()
ax.get_images()[0].set_extent((Qh[0], Qh[-1], Qk[0], Qk[-1])) 
plt.xlabel("H", size=22)
plt.ylabel("K", size=22)
plt.title(f'L={slice_value}')

# %% [markdown]
# ```
#
#
# clusterGMM.Plot_Cluster_kspace_2D_slice(threshold,figsize_,data_ind,slice_ind,axis_ind,cluster_list=None)
# ```
#
#
# Plots the 2D image slice, with each (thresholded) pixel color coded by the clustering label, or colored grey if not clustered.
# The input parameters are:
# ```
# threshold      : class Threshold_Background from Preprocessing
# figsize_       : size of image. If None, will not plot the image
# data_ind       : (h,k,l) or (h,k) indices of the data. shape=(num_data,2) or (num_data,3)
# slice_ind      : if 3D, the h/k/l index of the selected axis along which to take the data slice.
# axis_ind       : selected axis_ of slice_ind. 0 for l, 1 for k and 2 for h axis
# ```
#
# Output attributes for ploting with imshow(),
# ```
# clusterGMM.plot_image : 2D image to be plotted
# clusterGMM.plot_cmap  : color map for the clustering, matching the same color scheme of the cluster trajectories
# clusterGMM.plot_norm  : the norm to be used in imshow() so that cmap matches the cluster assignment integers
#
# ```

# %%
# a zoom in image of the above figure..
plt.figure(figsize=(10,10))

plt.imshow(clusterGMM.plot_image[200:300,0:100], origin='lower', cmap=clusterGMM.plot_cmap, norm=clusterGMM.plot_norm, extent=[Qh[0], Qh[100], Qk[200], Qk[300]])

plt.xlabel("H", size=22)
plt.ylabel("K", size=22)
plt.title(f'L={slice_value}', size=22)

# %% [markdown]
# Notice that CDW peaks at $q_{CDW} = (H+0.5,K+0.5,0)$ have overwhelmingly the same color matching the color of the order parameter like trajectory.

# %% [markdown]
# ### At this point, we can already see the CDW peaks and their intensity trajectory reflecting the order parameter.  The remaining steps are only to sharpen this result.

# %% [markdown]
# # Step G:  Identify the distinct cluster

# %% [markdown]
# There are other features such as the thermal diffuse scattering surrounding the Bragg peaks (trajectories increasing with $T$), and the noise at the centre of the reciprocal space. To focus on the more interesting features (the CDW and Bragg peaks), let us remove these noise like features and cluster the remaining trajectories again.
#
#
# ### Select the clusters you want to remove

# %%
Bad_Clusters=[0,1,3] # Select the list clusters to be removed: 0 for Red, 1 for blue, 2 for green, 3 for violet, 4 for yellow, 5 for orange, 6 for pink clusters...
# Note that the color assignments can change with each run.


# This block removes the data belonging to the bad clusters from the first clustering  
cluster_assignments = clusterGMM.cluster_assignments 
BadC_mask           = ~np.isin(cluster_assignments, Bad_Clusters)

Good_data              = Data_thresh[:,BadC_mask] 
Good_rescaled_data     = Rescaled_data[:,BadC_mask]   # the rescaled data belonging to the good clusters
Good_ind               = Data_ind[BadC_mask]          # (h,k,l) indices of the good data

# %% [markdown]
# ### Redo the GMM clustering with only the interesting clusters (steps E and F again)

# %%
num_clusters_2 = 3 # set the number of new clusters for the second step clustering  

Data_for_GMM_2 = Good_rescaled_data.transpose()


# Now perform the second step GMM clustering with the new filtered data (Data_for_GMM_2) and num_clusters_2 clusters 

clusterGMM_2 = GMM(Data_for_GMM_2, num_clusters_2)
clusterGMM_2.RunEM()

print('num of trajectories after second step clustering: =', clusterGMM_2.num_per_cluster)

# %% [markdown]
# Let us plot the cluster trajectories

# %%
clusterGMM_2.Plot_Cluster_Results_traj(Temp) 
plt.xlabel('T(K)', size=18)
plt.ylabel('$\widetilde{I}_q(T)$', size=18)
plt.title(' ')

# %% [markdown]
# Now we clearly see the order parameter like cluster. Let us plot and see which pixels in the  (ℎ,𝑘)  plane belong to the new clustering assignments.

# %%
plt.figure(figsize=(10,10))


axis_ind = 0   # Select 0 for plotting l plane, 1 for k plane, 2 for h plane 
slice_value = 0.0 # Value of the axis orthogonal to the selected plane
slice_ind = data.nxaxes[axis_ind+1].index(slice_value) # index of  the selected axis (h/k/l plane) to plot



Data_for_GMM_ind=Good_ind


clusterGMM_2.Plot_Cluster_kspace_2D_slice(threshold,None,Data_for_GMM_ind,slice_ind,axis_ind) 

plt.imshow(clusterGMM_2.plot_image[200:300,0:100],origin='lower',cmap=clusterGMM_2.plot_cmap,norm=clusterGMM_2.plot_norm,extent=[Qh[0], Qh[100], Qk[200], Qk[300]])
plt.xlabel("H",size=22)
plt.ylabel("K",size=22)
plt.title(f'L={slice_value}',size=22)

# %% [markdown]
# The bad clusters not selected for the second round clustering are now labeled as grey pixels.
# #### The order parameter trajectory is predominantly occupied by the CDW peaks.
#
# However, there are some neighbouring pixels assigned to different colors, when we expect them to correspond to same cluster. This is the consequence of neglecting correlations between neighboring points, and between different unit cells. These correlations are accounted for if we implement label smoothing procedure (XTEC-s).

# %% [markdown]
# # Final step: Physics!
#
# Store the clustered results and identify the physics in them

# %% [markdown]
# ### Plot the cluster averaged intensities to see the order parameter

# %%
plt.figure()
color_list = ['red', 'blue', 'green', 'purple', 'yellow', 'orange', 'pink', 'black', 'grey', 'cyan']

yc_plot={}
for i in range(clusterGMM_2.cluster_num):
    cluster_mask_i = (clusterGMM_2.cluster_assignments == i)
    yc_plot[i]=np.mean(Good_data[:,cluster_mask_i],axis=1).flatten()
    plt.plot(Temp,yc_plot[i],color=color_list[i], lw=2);

plt.yscale("linear")
plt.xlabel('T')
plt.ylabel('I (cluster avged)')

# %% [markdown]
# ### Store the final clustering results

# %%
import pickle

obj = {}
obj['Temp'] =  Temp  # 1 sigma var of the cluster trajectory, shape=(num_cluster,num_T)

obj['Data']          = Good_data.transpose()            # shape=(num_data, num_T)
obj['Data_ind']      = Good_ind # (hkl) indices of data, shape= (num_data,3)
obj['cluster_assignments'] = clusterGMM_2.cluster_assignments # cluster number = 0/1/2 for each data, shape=(num_data) 


obj['Num_clusters'] = clusterGMM_2.cluster_num
obj['cluster_mean'] = clusterGMM_2.means # mean trajectory of clusters, shape=(num_cluster, num_T)
obj['cluster_var'] =  clusterGMM_2.covs  # 1 sigma var of the cluster trajectory, shape=(num_cluster,num_T)

pickle.dump( obj, open( "csrs_0x0_clustering.p", "wb" ) )

# %% [markdown]
# # https://github.com/KimGroup/X-TEC
#
# ## Harnessing Interpretable and Unsupervised Machine Learning to Address Big Data from Modern X-ray Diffraction
#
# ### https://arxiv.org/abs/2008.03275
#
# ###### Jordan Venderley,  Krishnanand Mallaya, Michael Matty, Matthew Krogstad, Jacob Ruff, Geoff Pleiss, Varsha Kishore, David Mandrus, Daniel Phelan, Lekh Poudel, Andrew Gordon Wilson, Kilian Weinberger, Puspa Upreti, M. R. Norman, Stephan Rosenkranz, Raymond Osborn, Eun-Ah Kim
#
#
# ### Tutorial by Krishnanand Mallayya.
# ### For questions about X-TEC code and tutorial contact kmm537@cornell.edu (Krishnanand)
